# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
bookings = pd.read_csv('2_bookings.csv', sep=';')
bookings.head()
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.shape
# Out:
# (119390, 21)

# %% [markdown]
# ## 2

# %%
bookings_head = bookings[0:7]
bookings_head
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %% [markdown]
# ## 3

# %%
bookings.shape[1]
# Out:
# 21

# %% [markdown]
# ## 4

# %%
bookings.dtypes.value_counts()
# Out:
# object     10
# int64      10
# float64     1
# dtype: int64

# %% [markdown]
# ## 5

# %%
bookings.columns = bookings.columns.str.lower().str.replace(' ', '_')
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %% [markdown]
# ## 6

# %%
bookings[bookings.is_canceled == 0].country.value_counts()[:5]
# Out:
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# Name: country, dtype: int64

# %% [markdown]
# ## 7

# %%
bookings.groupby('hotel').stays_total_nights.mean().round(2)
# Out:
# hotel
# City Hotel      2.98
# Resort Hotel    4.32
# Name: stays_total_nights, dtype: float64

# %% [markdown]
# ## 8

# %%
sum(bookings.assigned_room_type != bookings.reserved_room_type)
# Out:
# 14917

# %% [markdown]
# ## 9

# %%
bookings[bookings.arrival_date_year == 2016].groupby('arrival_date_month').arrival_date_month.count().idxmax()
# Out:
# 'October'

# %%
bookings[bookings.arrival_date_year == 2017].groupby('arrival_date_month').arrival_date_month.count().idxmax()
# Out:
# 'May'

# %% [markdown]
# ## 10

# %%
bookings[(bookings.hotel == 'City Hotel')]\
        .groupby(['arrival_date_year', 'arrival_date_month'], as_index=False)\
        .is_canceled\
        .sum()\
        .sort_values(['arrival_date_year', 'is_canceled'], ascending=[True, False])
# Out:
#     arrival_date_year arrival_date_month  is_canceled
# 5                2015          September         1543
# 4                2015            October         1321
# 0                2015             August         1232
# 2                2015               July          939
# 1                2015           December          668
# 3                2015           November          301
# 16               2016            October         1947
# 12               2016               June         1720
# 17               2016          September         1567
# 6                2016              April         1539
# 14               2016                May         1436
# 15               2016           November         1360
# 7                2016             August         1247
# 13               2016              March         1108
# 8                2016           December         1072
# 11               2016               July         1043
# ...

# %% [markdown]
# ## 11

# %%
bookings[['adults', 'children', 'babies']].mean()
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %% [markdown]
# ## 12

# %%
bookings['total_kids'] = bookings.children + bookings.babies

# %%
bookings.groupby('hotel').total_kids.mean().sort_values(ascending=False)[0].round(2)
# Out:
# 0.14

# %% [markdown]
# ## 13

# %%
bookings['has_kids'] = bookings.total_kids > 0

# %%
100 * bookings.groupby('has_kids').is_canceled.mean().round(4).max()
# Out:
# 37.22

# %%
bookings.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...
